# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 1.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
import warnings
warnings.filterwarnings('ignore') # too many warnings (use DataFrame.transpose instead of DataFrame.swapaxes)

col_names = ['ch1','ch2','ch3','ch4','ch5','ch6']

#bitrate = 100

for i in range(10): # data1 to data10
    for j in ['ironman','fist','release']:
        globals()['{}_{}'.format(j,i+1)] = pd.read_excel('/Users/jhr/owndata/{}/{}.xlsm'.format(j,i+1), names=col_names)
        globals()['{}_{}'.format(j,i+1)] = globals()['{}_{}'.format(j,i+1)].to_numpy()

# %%
ironman_1
# Out:
# array([[162,  31,  54,  30,  33,  27],
#        [150,  34,  63,  35,  32,  27],
#        [176,  34,  63,  41,  32,  27],
#        ...,
#        [ 60,  34,  48,  29,  33,  27],
#        [100,  34,  39,  30,  32,  27],
#        [ 81,  34,  42,  29,  32,  27]])

# %%
ironman_2
# Out:
# array([[127,  33,  59,  35,  33,  27],
#        [140,  35,  52,  35,  33,  27],
#        [151,  32,  66,  41,  33,  27],
#        ...,
#        [ 28,  32,  24,  29,  33,  27],
#        [ 28,  33,  24,  29,  33,  27],
#        [ 28,  31,  24,  29,  32,  27]])

# %%
fig, axs = plt.subplots(3,1, figsize=(16,12))

jesture = ['ironman','fist','release']
for i in range(3):
    axs[i].plot(globals()['{}_1'.format(jesture[i])])   
    axs[i].set_title('{}'.format(jesture[i]))
    axs[i].legend(col_names)

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)

ax.plot(ironman_2[28:55,:], label='1',alpha=0.6)

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)

ax.plot(fist_2[50:80,:], label='1',alpha=0.6)

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)

ax.plot(release_2[35:64,:], label='1',alpha=0.6)
